# %% [markdown]
# ## Using Boto3 to work with ec2 instances. like list all instances, create instances, stop instances

# %%
import boto3
from pprint import pprint
import sys

import time

# %% [markdown]
# ## We are using client object to describe ec2 instances

# %%
def describe_instances_client():
    """This function list All instance using client object. 
    Parameter: None
    Return: None
    """
    client = boto3.session.Session().client('ec2', 'us-east-1')
    response = client.describe_instances().get('Reservations')
    for instance in response:
        for each_instance in instance.get('Instances'):
            pprint(each_instance)
            # print("=================")
            print(f"Instance_id: {each_instance.get('InstanceId')}\nLaunchTime is: {each_instance.get('LaunchTime').strftime('%y-%m-%d')}\nInstance Status: {each_instance.get('State').get('Name')}")
    return None        
    
   
describe_instances_client()
# Out:
# {'AmiLaunchIndex': 0,
#  'Architecture': 'x86_64',
#  'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#                           'Ebs': {'AttachTime': datetime.datetime(2022, 6, 25, 17, 9, 5, tzinfo=tzutc()),
#                                   'DeleteOnTermination': True,
#                                   'Status': 'attached',
#                                   'VolumeId': 'vol-0675a685649c7aec6'}}],
#  'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#  'ClientToken': 'C225F08F-4857-4F6D-8C1F-1013C1D65E60',
#  'CpuOptions': {'CoreCount': 4, 'ThreadsPerCore': 1},
#  'EbsOptimized': False,
#  'EnaSupport': True,
#  'EnclaveOptions': {'Enabled': False},
#  'HibernationOptions': {'Configured': False},
#  'Hypervisor': 'xen',
#  'IamInstanceProfile': {'Arn': 'arn:aws:iam::735972722491:instance-profile/instance_profile',
#                         'Id': 'AIPA2WW3EQ45WBXJYE3CU'},
#  'ImageId': 'ami-065efef2c739d613b',
#  'InstanceId': 'i-006036d9646165a19',
#  'InstanceType': 't2.xlarge',
#  'LaunchTime': datetime.datetime(2022, 6, 25, 17, 9, 5, tzinfo=tzutc()),
#  'MaintenanceOptions': {'AutoRecovery': 'default'},
#  'MetadataOptions': {'HttpEndpoint': 'enabled',
#                      'HttpProtocolIpv6': 'disabled',
#                      'HttpPutResponseHopLimit': 1,
#                      'HttpTokens': 'optional',
#                      'InstanceMetadataTags': 'disabled',
#                      'State': 'applied'},
#  'Monitoring': {'State': 'disabled'},
#  'NetworkInterfaces': [{'Attachment': {'AttachTime': datetime.datetime(2022, 6, 25, 17, 9, 5, tzinfo=tzutc()),
#                                        'AttachmentId': 'eni-attach-040739ecb3c4632ea',
#                                        'DeleteOnTermination': True,
#                                        'DeviceIndex': 0,
#                                        'NetworkCardIndex': 0,
#                                        'Status': 'attached'},
#                         'Description': '',
#                         'Groups': [{'GroupId': 'sg-056be8840d6eb3b00',
#                                     'GroupName': 'front_app_sg'}],
#                         'InterfaceType': 'interface',
#                         'Ipv6Addresses': [],
#                         'MacAddress': '0a:22:e6:fb:c2:5b',
#                         'NetworkInterfaceId': 'eni-09d286e6e9bbe01db',
#                         'OwnerId': '735972722491',
#                         'PrivateDnsName': 'ip-10-0-3-222.ec2.internal',
#                         'PrivateIpAddress': '10.0.3.222',
#                         'PrivateIpAddresses': [{'Primary': True,
#                                                 'PrivateDnsName': 'ip-10-0-3-222.ec2.internal',
#                                                 'PrivateIpAddress': '10.0.3.222'}],
#                         'SourceDestCheck': True,
#                         'Status': 'in-use',
#                         'SubnetId': 'subnet-0bdc684c28ed6efee',
#                         'VpcId': 'vpc-0d458168a93a65a2c'}],
#  'Placement': {'AvailabilityZone': 'us-east-1b',
#                'GroupName': '',
#                'Tenancy': 'default'},
#  'PlatformDetails': 'Linux/UNIX',
#  'PrivateDnsName': 'ip-10-0-3-222.ec2.internal',
#  'PrivateDnsNameOptions': {'EnableResourceNameDnsAAAARecord': False,
#                            'EnableResourceNameDnsARecord': False,
#                            'HostnameType': 'ip-name'},
#  'PrivateIpAddress': '10.0.3.222',
#  'ProductCodes': [],
#  'PublicDnsName': '',
#  'RootDeviceName': '/dev/xvda',
#  'RootDeviceType': 'ebs',
#  'SecurityGroups': [{'GroupId': 'sg-056be8840d6eb3b00',
#                      'GroupName': 'front_app_sg'}],
#  'SourceDestCheck': True,
#  'State': {'Code': 16, 'Name': 'running'},
#  'StateTransitionReason': '',
#  'SubnetId': 'subnet-0bdc684c28ed6efee',
#  'Tags': [{'Key': 'operational_environment', 'Value': 'PROD'},
#           {'Key': 'vpc', 'Value': 'WEB'},
#           {'Key': 'application_owner', 'Value': 'kojitechs.com'},
#           {'Key': 'tech_poc_primary', 'Value': 'udu.udu25@gmail.com'},
#           {'Key': 'builder', 'Value': 'udu.udu25@gmail.com'},
#           {'Key': 'tech_poc_secondary', 'Value': 'udu.udu25@gmail.com'},
#           {'Key': 'line_of_business', 'Value': 'hospital'},
#           {'Key': 'Name', 'Value': 'app2'},
#           {'Key': 'cell_name', 'Value': 'WEB'},
#           {'Key': 'ado', 'Value': 'max'},
#           {'Key': 'application', 'Value': 'http'},
#           {'Key': 'tier', 'Value': 'WEB'},
#           {'Key': 'component_name', 'Value': 'kojitechs'}],
#  'UsageOperation': 'RunInstances',
#  'UsageOperationUpdateTime': datetime.datetime(2022, 6, 25, 17, 9, 5, tzinfo=tzutc()),
#  'VirtualizationType': 'hvm',
#  'VpcId': 'vpc-0d458168a93a65a2c'}
# Instance_id: i-006036d9646165a19
# LaunchTime is: 22-06-25
# Instance Status: running
# {'AmiLaunchIndex': 1,
#  'Architecture': 'x86_64',
#  'BlockDeviceMappings': [],
#  'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#  'ClientToken': '',
#  'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#  'EbsOptimized': False,
#  'EnaSupport': True,
#  'EnclaveOptions': {'Enabled': False},
#  'HibernationOptions': {'Configured': False},
#  'Hypervisor': 'xen',
#  'ImageId': 'ami-0cff7528ff583bf9a',
#  'InstanceId': 'i-04152ff8a36c26092',
#  'InstanceType': 't2.micro',
#  'KeyName': 'testkeypair',
#  'LaunchTime': datetime.datetime(2022, 6, 25, 16, 58, 17, tzinfo=tzutc()),
#  'MaintenanceOptions': {'AutoRecovery': 'default'},
#  'MetadataOptions': {'HttpEndpoint': 'enabled',
#                      'HttpProtocolIpv6': 'disabled',
#                      'HttpPutResponseHopLimit': 1,
#                      'HttpTokens': 'optional',
#                      'InstanceMetadataTags': 'disabled',
#                      'State': 'pending'},
#  'Monitoring': {'State': 'disabled'},
#  'NetworkInterfaces': [],
#  'Placement': {'AvailabilityZone': 'us-east-1a',
#                'GroupName': '',
#                'Tenancy': 'default'},
#  'PlatformDetails': 'Linux/UNIX',
#  'PrivateDnsName': '',
#  'ProductCodes': [],
#  'PublicDnsName': '',
#  'RootDeviceName': '/dev/xvda',
#  'RootDeviceType': 'ebs',
#  'SecurityGroups': [],
#  'State': {'Code': 48, 'Name': 'terminated'},
#  'StateReason': {'Code': 'Client.UserInitiatedShutdown',
#                  'Message': 'Client.UserInitiatedShutdown: User initiated '
#                             'shutdown'},
#  'StateTransitionReason': 'User initiated (2022-06-25 16:58:56 GMT)',
#  'Tags': [{'Key': 'Name', 'Value': 'Python-boto3'}],
#  'UsageOperation': 'RunInstances',
#  'UsageOperationUpdateTime': datetime.datetime(2022, 6, 25, 14, 2, 52, tzinfo=tzutc()),
#  'VirtualizationType': 'hvm'}
# Instance_id: i-04152ff8a36c26092
# LaunchTime is: 22-06-25
# Instance Status: terminated
# {'AmiLaunchIndex': 2,
#  'Architecture': 'x86_64',
#  'BlockDeviceMappings': [],
#  'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#  'ClientToken': '',
#  'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#  'EbsOptimized': False,
#  'EnaSupport': True,
#  'EnclaveOptions': {'Enabled': False},
#  'HibernationOptions': {'Configured': False},
#  'Hypervisor': 'xen',
#  'ImageId': 'ami-0cff7528ff583bf9a',
#  'InstanceId': 'i-07a05e49233b43a32',
#  'InstanceType': 't2.micro',
#  'KeyName': 'testkeypair',
#  'LaunchTime': datetime.datetime(2022, 6, 25, 16, 58, 17, tzinfo=tzutc()),
#  'MaintenanceOptions': {'AutoRecovery': 'default'},
#  'MetadataOptions': {'HttpEndpoint': 'enabled',
#                      'HttpProtocolIpv6': 'disabled',
#                      'HttpPutResponseHopLimit': 1,
#                      'HttpTokens': 'optional',
#                      'InstanceMetadataTags': 'disabled',
#                      'State': 'pending'},
#  'Monitoring': {'State': 'disabled'},
#  'NetworkInterfaces': [],
#  'Placement': {'AvailabilityZone': 'us-east-1a',
#                'GroupName': '',
#                'Tenancy': 'default'},
#  'PlatformDetails': 'Linux/UNIX',
#  'PrivateDnsName': '',
#  'ProductCodes': [],
#  'PublicDnsName': '',
#  'RootDeviceName': '/dev/xvda',
#  'RootDeviceType': 'ebs',
#  'SecurityGroups': [],
#  'State': {'Code': 48, 'Name': 'terminated'},
#  'StateReason': {'Code': 'Client.UserInitiatedShutdown',
#                  'Message': 'Client.UserInitiatedShutdown: User initiated '
#                             'shutdown'},
#  'StateTransitionReason': 'User initiated (2022-06-25 16:58:56 GMT)',
#  'Tags': [{'Key': 'Name', 'Value': 'Python-boto3'}],
#  'UsageOperation': 'RunInstances',
#  'UsageOperationUpdateTime': datetime.datetime(2022, 6, 25, 14, 2, 52, tzinfo=tzutc()),
#  'VirtualizationType': 'hvm'}
# Instance_id: i-07a05e49233b43a32
# LaunchTime is: 22-06-25
# Instance Status: terminated
# {'AmiLaunchIndex': 0,
#  'Architecture': 'x86_64',
#  'BlockDeviceMappings': [],
#  'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#  'ClientToken': '',
#  'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#  'EbsOptimized': False,
#  'EnaSupport': True,
#  'EnclaveOptions': {'Enabled': False},
#  'HibernationOptions': {'Configured': False},
#  'Hypervisor': 'xen',
#  'ImageId': 'ami-0cff7528ff583bf9a',
#  'InstanceId': 'i-08ea86bebd2bc9ae7',
#  'InstanceType': 't2.micro',
#  'KeyName': 'testkeypair',
#  'LaunchTime': datetime.datetime(2022, 6, 25, 16, 58, 17, tzinfo=tzutc()),
#  'MaintenanceOptions': {'AutoRecovery': 'default'},
#  'MetadataOptions': {'HttpEndpoint': 'enabled',
#                      'HttpProtocolIpv6': 'disabled',
#                      'HttpPutResponseHopLimit': 1,
#                      'HttpTokens': 'optional',
#                      'InstanceMetadataTags': 'disabled',
#                      'State': 'pending'},
#  'Monitoring': {'State': 'disabled'},
#  'NetworkInterfaces': [],
#  'Placement': {'AvailabilityZone': 'us-east-1a',
#                'GroupName': '',
#                'Tenancy': 'default'},
#  'PlatformDetails': 'Linux/UNIX',
#  'PrivateDnsName': '',
#  'ProductCodes': [],
#  'PublicDnsName': '',
#  'RootDeviceName': '/dev/xvda',
#  'RootDeviceType': 'ebs',
#  'SecurityGroups': [],
#  'State': {'Code': 48, 'Name': 'terminated'},
#  'StateReason': {'Code': 'Client.UserInitiatedShutdown',
#                  'Message': 'Client.UserInitiatedShutdown: User initiated '
#                             'shutdown'},
#  'StateTransitionReason': 'User initiated (2022-06-25 16:58:56 GMT)',
#  'Tags': [{'Key': 'Name', 'Value': 'Python-boto3'}],
#  'UsageOperation': 'RunInstances',
#  'UsageOperationUpdateTime': datetime.datetime(2022, 6, 25, 14, 2, 52, tzinfo=tzutc()),
#  'VirtualizationType': 'hvm'}
# Instance_id: i-08ea86bebd2bc9ae7
# LaunchTime is: 22-06-25
# Instance Status: terminated
# {'AmiLaunchIndex': 2,
#  'Architecture': 'x86_64',
#  'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#                           'Ebs': {'AttachTime': datetime.datetime(2022, 6, 25, 17, 0, 14, tzinfo=tzutc()),
#                                   'DeleteOnTermination': True,
#                                   'Status': 'attached',
#                                   'VolumeId': 'vol-0b5d6b8086075e6fb'}}],
#  'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#  'ClientToken': '',
#  'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#  'EbsOptimized': False,
#  'EnaSupport': True,
#  'EnclaveOptions': {'Enabled': False},
#  'HibernationOptions': {'Configured': False},
#  'Hypervisor': 'xen',
#  'ImageId': 'ami-0cff7528ff583bf9a',
#  'InstanceId': 'i-0402675382b992f7a',
#  'InstanceType': 't2.micro',
#  'KeyName': 'testkeypair',
#  'LaunchTime': datetime.datetime(2022, 6, 25, 17, 0, 13, tzinfo=tzutc()),
#  'MaintenanceOptions': {'AutoRecovery': 'default'},
#  'MetadataOptions': {'HttpEndpoint': 'enabled',
#                      'HttpProtocolIpv6': 'disabled',
#                      'HttpPutResponseHopLimit': 1,
#                      'HttpTokens': 'optional',
#                      'InstanceMetadataTags': 'disabled',
#                      'State': 'applied'},
#  'Monitoring': {'State': 'disabled'},
#  'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#                                         'PublicDnsName': 'ec2-54-86-101-7.compute-1.amazonaws.com',
#                                         'PublicIp': '54.86.101.7'},
#                         'Attachment': {'AttachTime': datetime.datetime(2022, 6, 25, 17, 0, 13, tzinfo=tzutc()),
#                                        'AttachmentId': 'eni-attach-0219bc8d4432ae038',
#                                        'DeleteOnTermination': True,
#                                        'DeviceIndex': 0,
#                                        'NetworkCardIndex': 0,
#                                        'Status': 'attached'},
#                         'Description': '',
#                         'Groups': [{'GroupId': 'sg-08c7594d7f3481e49',
#                                     'GroupName': 'launch-wizard-3'}],
#                         'InterfaceType': 'interface',
#                         'Ipv6Addresses': [],
#                         'MacAddress': '12:14:ba:6f:3b:7b',
#                         'NetworkInterfaceId': 'eni-043b1db0b207e60d9',
#                         'OwnerId': '735972722491',
#                         'PrivateDnsName': 'ip-172-31-80-71.ec2.internal',
#                         'PrivateIpAddress': '172.31.80.71',
#                         'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#                                                                 'PublicDnsName': 'ec2-54-86-101-7.compute-1.amazonaws.com',
#                                                                 'PublicIp': '54.86.101.7'},
#                                                 'Primary': True,
#                                                 'PrivateDnsName': 'ip-172-31-80-71.ec2.internal',
#                                                 'PrivateIpAddress': '172.31.80.71'}],
#                         'SourceDestCheck': True,
#                         'Status': 'in-use',
#                         'SubnetId': 'subnet-3aac1e1b',
#                         'VpcId': 'vpc-18468665'}],
#  'Placement': {'AvailabilityZone': 'us-east-1a',
#                'GroupName': '',
#                'Tenancy': 'default'},
#  'PlatformDetails': 'Linux/UNIX',
#  'PrivateDnsName': 'ip-172-31-80-71.ec2.internal',
#  'PrivateDnsNameOptions': {'EnableResourceNameDnsAAAARecord': False,
#                            'EnableResourceNameDnsARecord': True,
#                            'HostnameType': 'ip-name'},
#  'PrivateIpAddress': '172.31.80.71',
#  'ProductCodes': [],
#  'PublicDnsName': 'ec2-54-86-101-7.compute-1.amazonaws.com',
#  'PublicIpAddress': '54.86.101.7',
#  'RootDeviceName': '/dev/xvda',
#  'RootDeviceType': 'ebs',
#  'SecurityGroups': [{'GroupId': 'sg-08c7594d7f3481e49',
#                      'GroupName': 'launch-wizard-3'}],
#  'SourceDestCheck': True,
#  'State': {'Code': 16, 'Name': 'running'},
#  'StateTransitionReason': '',
#  'SubnetId': 'subnet-3aac1e1b',
#  'Tags': [{'Key': 'Name', 'Value': 'python-boto3'}],
#  'UsageOperation': 'RunInstances',
#  'UsageOperationUpdateTime': datetime.datetime(2022, 6, 25, 17, 0, 13, tzinfo=tzutc()),
#  'VirtualizationType': 'hvm',
#  'VpcId': 'vpc-18468665'}
# Instance_id: i-0402675382b992f7a
# LaunchTime is: 22-06-25
# Instance Status: running
# {'AmiLaunchIndex': 0,
#  'Architecture': 'x86_64',
#  'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#                           'Ebs': {'AttachTime': datetime.datetime(2022, 6, 25, 17, 0, 14, tzinfo=tzutc()),
#                                   'DeleteOnTermination': True,
#                                   'Status': 'attached',
#                                   'VolumeId': 'vol-0b7f76083002c8169'}}],
#  'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#  'ClientToken': '',
#  'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#  'EbsOptimized': False,
#  'EnaSupport': True,
#  'EnclaveOptions': {'Enabled': False},
#  'HibernationOptions': {'Configured': False},
#  'Hypervisor': 'xen',
#  'ImageId': 'ami-0cff7528ff583bf9a',
#  'InstanceId': 'i-089999e2cced39b86',
#  'InstanceType': 't2.micro',
#  'KeyName': 'testkeypair',
#  'LaunchTime': datetime.datetime(2022, 6, 25, 17, 0, 13, tzinfo=tzutc()),
#  'MaintenanceOptions': {'AutoRecovery': 'default'},
#  'MetadataOptions': {'HttpEndpoint': 'enabled',
#                      'HttpProtocolIpv6': 'disabled',
#                      'HttpPutResponseHopLimit': 1,
#                      'HttpTokens': 'optional',
#                      'InstanceMetadataTags': 'disabled',
#                      'State': 'applied'},
#  'Monitoring': {'State': 'disabled'},
#  'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#                                         'PublicDnsName': 'ec2-54-89-138-165.compute-1.amazonaws.com',
#                                         'PublicIp': '54.89.138.165'},
#                         'Attachment': {'AttachTime': datetime.datetime(2022, 6, 25, 17, 0, 13, tzinfo=tzutc()),
#                                        'AttachmentId': 'eni-attach-0dfe0b63c4db73077',
#                                        'DeleteOnTermination': True,
#                                        'DeviceIndex': 0,
#                                        'NetworkCardIndex': 0,
#                                        'Status': 'attached'},
#                         'Description': '',
#                         'Groups': [{'GroupId': 'sg-08c7594d7f3481e49',
#                                     'GroupName': 'launch-wizard-3'}],
#                         'InterfaceType': 'interface',
#                         'Ipv6Addresses': [],
#                         'MacAddress': '12:f0:cf:76:36:8d',
#                         'NetworkInterfaceId': 'eni-0e5e926274dcbafb8',
#                         'OwnerId': '735972722491',
#                         'PrivateDnsName': 'ip-172-31-93-226.ec2.internal',
#                         'PrivateIpAddress': '172.31.93.226',
#                         'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#                                                                 'PublicDnsName': 'ec2-54-89-138-165.compute-1.amazonaws.com',
#                                                                 'PublicIp': '54.89.138.165'},
#                                                 'Primary': True,
#                                                 'PrivateDnsName': 'ip-172-31-93-226.ec2.internal',
#                                                 'PrivateIpAddress': '172.31.93.226'}],
#                         'SourceDestCheck': True,
#                         'Status': 'in-use',
#                         'SubnetId': 'subnet-3aac1e1b',
#                         'VpcId': 'vpc-18468665'}],
#  'Placement': {'AvailabilityZone': 'us-east-1a',
#                'GroupName': '',
#                'Tenancy': 'default'},
#  'PlatformDetails': 'Linux/UNIX',
#  'PrivateDnsName': 'ip-172-31-93-226.ec2.internal',
#  'PrivateDnsNameOptions': {'EnableResourceNameDnsAAAARecord': False,
#                            'EnableResourceNameDnsARecord': True,
#                            'HostnameType': 'ip-name'},
#  'PrivateIpAddress': '172.31.93.226',
#  'ProductCodes': [],
#  'PublicDnsName': 'ec2-54-89-138-165.compute-1.amazonaws.com',
#  'PublicIpAddress': '54.89.138.165',
#  'RootDeviceName': '/dev/xvda',
#  'RootDeviceType': 'ebs',
#  'SecurityGroups': [{'GroupId': 'sg-08c7594d7f3481e49',
#                      'GroupName': 'launch-wizard-3'}],
#  'SourceDestCheck': True,
#  'State': {'Code': 16, 'Name': 'running'},
#  'StateTransitionReason': '',
#  'SubnetId': 'subnet-3aac1e1b',
#  'Tags': [{'Key': 'Name', 'Value': 'python-boto3'}],
#  'UsageOperation': 'RunInstances',
#  'UsageOperationUpdateTime': datetime.datetime(2022, 6, 25, 17, 0, 13, tzinfo=tzutc()),
#  'VirtualizationType': 'hvm',
#  'VpcId': 'vpc-18468665'}
# Instance_id: i-089999e2cced39b86
# LaunchTime is: 22-06-25
# Instance Status: running
# {'AmiLaunchIndex': 1,
#  'Architecture': 'x86_64',
#  'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#                           'Ebs': {'AttachTime': datetime.datetime(2022, 6, 25, 17, 0, 14, tzinfo=tzutc()),
#                                   'DeleteOnTermination': True,
#                                   'Status': 'attached',
#                                   'VolumeId': 'vol-0f2b58920eeb50227'}}],
#  'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#  'ClientToken': '',
#  'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#  'EbsOptimized': False,
#  'EnaSupport': True,
#  'EnclaveOptions': {'Enabled': False},
#  'HibernationOptions': {'Configured': False},
#  'Hypervisor': 'xen',
#  'ImageId': 'ami-0cff7528ff583bf9a',
#  'InstanceId': 'i-09135aa74c2e472d7',
#  'InstanceType': 't2.micro',
#  'KeyName': 'testkeypair',
#  'LaunchTime': datetime.datetime(2022, 6, 25, 17, 0, 13, tzinfo=tzutc()),
#  'MaintenanceOptions': {'AutoRecovery': 'default'},
#  'MetadataOptions': {'HttpEndpoint': 'enabled',
#                      'HttpProtocolIpv6': 'disabled',
#                      'HttpPutResponseHopLimit': 1,
#                      'HttpTokens': 'optional',
#                      'InstanceMetadataTags': 'disabled',
#                      'State': 'applied'},
#  'Monitoring': {'State': 'disabled'},
#  'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#                                         'PublicDnsName': 'ec2-34-207-122-226.compute-1.amazonaws.com',
#                                         'PublicIp': '34.207.122.226'},
#                         'Attachment': {'AttachTime': datetime.datetime(2022, 6, 25, 17, 0, 13, tzinfo=tzutc()),
#                                        'AttachmentId': 'eni-attach-0d6d752292b38cf1d',
#                                        'DeleteOnTermination': True,
#                                        'DeviceIndex': 0,
#                                        'NetworkCardIndex': 0,
#                                        'Status': 'attached'},
#                         'Description': '',
#                         'Groups': [{'GroupId': 'sg-08c7594d7f3481e49',
#                                     'GroupName': 'launch-wizard-3'}],
#                         'InterfaceType': 'interface',
#                         'Ipv6Addresses': [],
#                         'MacAddress': '12:36:2a:b4:0f:61',
#                         'NetworkInterfaceId': 'eni-08dd98c1b9d5ade54',
#                         'OwnerId': '735972722491',
#                         'PrivateDnsName': 'ip-172-31-90-5.ec2.internal',
#                         'PrivateIpAddress': '172.31.90.5',
#                         'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#                                                                 'PublicDnsName': 'ec2-34-207-122-226.compute-1.amazonaws.com',
#                                                                 'PublicIp': '34.207.122.226'},
#                                                 'Primary': True,
#                                                 'PrivateDnsName': 'ip-172-31-90-5.ec2.internal',
#                                                 'PrivateIpAddress': '172.31.90.5'}],
#                         'SourceDestCheck': True,
#                         'Status': 'in-use',
#                         'SubnetId': 'subnet-3aac1e1b',
#                         'VpcId': 'vpc-18468665'}],
#  'Placement': {'AvailabilityZone': 'us-east-1a',
#                'GroupName': '',
#                'Tenancy': 'default'},
#  'PlatformDetails': 'Linux/UNIX',
#  'PrivateDnsName': 'ip-172-31-90-5.ec2.internal',
#  'PrivateDnsNameOptions': {'EnableResourceNameDnsAAAARecord': False,
#                            'EnableResourceNameDnsARecord': True,
#                            'HostnameType': 'ip-name'},
#  'PrivateIpAddress': '172.31.90.5',
#  'ProductCodes': [],
#  'PublicDnsName': 'ec2-34-207-122-226.compute-1.amazonaws.com',
#  'PublicIpAddress': '34.207.122.226',
#  'RootDeviceName': '/dev/xvda',
#  'RootDeviceType': 'ebs',
#  'SecurityGroups': [{'GroupId': 'sg-08c7594d7f3481e49',
#                      'GroupName': 'launch-wizard-3'}],
#  'SourceDestCheck': True,
#  'State': {'Code': 16, 'Name': 'running'},
#  'StateTransitionReason': '',
#  'SubnetId': 'subnet-3aac1e1b',
#  'Tags': [{'Key': 'Name', 'Value': 'python-boto3'}],
#  'UsageOperation': 'RunInstances',
#  'UsageOperationUpdateTime': datetime.datetime(2022, 6, 25, 17, 0, 13, tzinfo=tzutc()),
#  'VirtualizationType': 'hvm',
#  'VpcId': 'vpc-18468665'}
# Instance_id: i-09135aa74c2e472d7
# LaunchTime is: 22-06-25
# Instance Status: running
# {'AmiLaunchIndex': 0,
#  'Architecture': 'x86_64',
#  'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#                           'Ebs': {'AttachTime': datetime.datetime(2022, 6, 25, 17, 9, 5, tzinfo=tzutc()),
#                                   'DeleteOnTermination': True,
#                                   'Status': 'attached',
#                                   'VolumeId': 'vol-06f6e94bc49173647'}}],
#  'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#  'ClientToken': 'C305A727-847D-4A19-AAF4-397BDCDAFE5F',
#  'CpuOptions': {'CoreCount': 4, 'ThreadsPerCore': 1},
#  'EbsOptimized': False,
#  'EnaSupport': True,
#  'EnclaveOptions': {'Enabled': False},
#  'HibernationOptions': {'Configured': False},
#  'Hypervisor': 'xen',
#  'IamInstanceProfile': {'Arn': 'arn:aws:iam::735972722491:instance-profile/instance_profile',
#                         'Id': 'AIPA2WW3EQ45WBXJYE3CU'},
#  'ImageId': 'ami-065efef2c739d613b',
#  'InstanceId': 'i-03ddf11ab7549eb7c',
#  'InstanceType': 't2.xlarge',
#  'LaunchTime': datetime.datetime(2022, 6, 25, 17, 9, 5, tzinfo=tzutc()),
#  'MaintenanceOptions': {'AutoRecovery': 'default'},
#  'MetadataOptions': {'HttpEndpoint': 'enabled',
#                      'HttpProtocolIpv6': 'disabled',
#                      'HttpPutResponseHopLimit': 1,
#                      'HttpTokens': 'optional',
#                      'InstanceMetadataTags': 'disabled',
#                      'State': 'applied'},
#  'Monitoring': {'State': 'disabled'},
#  'NetworkInterfaces': [{'Attachment': {'AttachTime': datetime.datetime(2022, 6, 25, 17, 9, 5, tzinfo=tzutc()),
#                                        'AttachmentId': 'eni-attach-0bd5e16f095d9cc34',
#                                        'DeleteOnTermination': True,
#                                        'DeviceIndex': 0,
#                                        'NetworkCardIndex': 0,
#                                        'Status': 'attached'},
#                         'Description': '',
#                         'Groups': [{'GroupId': 'sg-056be8840d6eb3b00',
#                                     'GroupName': 'front_app_sg'}],
#                         'InterfaceType': 'interface',
#                         'Ipv6Addresses': [],
#                         'MacAddress': '12:97:36:bc:06:e1',
#                         'NetworkInterfaceId': 'eni-0bb1120b1daebfb2d',
#                         'OwnerId': '735972722491',
#                         'PrivateDnsName': 'ip-10-0-1-165.ec2.internal',
#                         'PrivateIpAddress': '10.0.1.165',
#                         'PrivateIpAddresses': [{'Primary': True,
#                                                 'PrivateDnsName': 'ip-10-0-1-165.ec2.internal',
#                                                 'PrivateIpAddress': '10.0.1.165'}],
#                         'SourceDestCheck': True,
#                         'Status': 'in-use',
#                         'SubnetId': 'subnet-06b2f6833a217f30f',
#                         'VpcId': 'vpc-0d458168a93a65a2c'}],
#  'Placement': {'AvailabilityZone': 'us-east-1a',
#                'GroupName': '',
#                'Tenancy': 'default'},
#  'PlatformDetails': 'Linux/UNIX',
#  'PrivateDnsName': 'ip-10-0-1-165.ec2.internal',
#  'PrivateDnsNameOptions': {'EnableResourceNameDnsAAAARecord': False,
#                            'EnableResourceNameDnsARecord': False,
#                            'HostnameType': 'ip-name'},
#  'PrivateIpAddress': '10.0.1.165',
#  'ProductCodes': [],
#  'PublicDnsName': '',
#  'RootDeviceName': '/dev/xvda',
#  'RootDeviceType': 'ebs',
#  'SecurityGroups': [{'GroupId': 'sg-056be8840d6eb3b00',
#                      'GroupName': 'front_app_sg'}],
#  'SourceDestCheck': True,
#  'State': {'Code': 16, 'Name': 'running'},
#  'StateTransitionReason': '',
#  'SubnetId': 'subnet-06b2f6833a217f30f',
#  'Tags': [{'Key': 'tier', 'Value': 'WEB'},
#           {'Key': 'builder', 'Value': 'udu.udu25@gmail.com'},
#           {'Key': 'Name', 'Value': 'app1'},
#           {'Key': 'ado', 'Value': 'max'},
#           {'Key': 'component_name', 'Value': 'kojitechs'},
#           {'Key': 'cell_name', 'Value': 'WEB'},
#           {'Key': 'line_of_business', 'Value': 'hospital'},
#           {'Key': 'operational_environment', 'Value': 'PROD'},
#           {'Key': 'application_owner', 'Value': 'kojitechs.com'},
#           {'Key': 'tech_poc_primary', 'Value': 'udu.udu25@gmail.com'},
#           {'Key': 'tech_poc_secondary', 'Value': 'udu.udu25@gmail.com'},
#           {'Key': 'vpc', 'Value': 'WEB'},
#           {'Key': 'application', 'Value': 'http'}],
#  'UsageOperation': 'RunInstances',
#  'UsageOperationUpdateTime': datetime.datetime(2022, 6, 25, 17, 9, 5, tzinfo=tzutc()),
#  'VirtualizationType': 'hvm',
#  'VpcId': 'vpc-0d458168a93a65a2c'}
# Instance_id: i-03ddf11ab7549eb7c
# LaunchTime is: 22-06-25
# Instance Status: running

# %% [markdown]
# ## Describe instances using resource object.

# %%
def describe_instances_resource():
    """This function list All instance using resource object. 
    Parameter: None
    Return: instance_ids
    """
    instance_ids = []
    resource = boto3.session.Session().resource('ec2', 'us-east-1')
    response = resource.instances.all()
    for each_instance in response:
        instance_ids.append(each_instance.id)
    return instance_ids

instance_ids = describe_instances_resource()
print(instance_ids)
# Out:
# ['i-0402675382b992f7a', 'i-089999e2cced39b86', 'i-09135aa74c2e472d7']

# %% [markdown]
# ## Using client object to stop or start an instance.

# %%
def stopping_instances_cli(ids):
    """This function stop All instance using client object if running. 
    Parameter: instanceIds(list)
    Return: None
    """
    client = boto3.session.Session().client('ec2', 'us-east-1')
    print("Stopping all instances.....")
    client.stop_instances(InstanceIds=ids)
    time.sleep(20)
    print("instances stopped!!.....")
    return None


stopping_instances_cli(['i-07a05e49233b43a32'])
# Out:
# Stopping all instances.....
# instances stopped!!.....

# %%
def starting_instances_cli(ids):
    """This function start All instance using client object if running. 
    Parameter: instanceIds(list)
    Return: None
    """
    client = boto3.session.Session().client('ec2', 'us-east-1')
    print("Starting all instances.....")
    client.start_instances(InstanceIds=ids)
    time.sleep(20)
    print("started instances!!.....")
    return None

# %%
stopping_instances_cli(instance_ids)
# Out:
# Stopping all instances.....
# instances stopped!!.....

# %%
starting_instances_cli(instance_ids)
# Out:
# Starting all instances.....
# instances start!!.....

# %%
def melo_driven_script():
    """This function is to perform actions like terminate, stop, start, and exit bases on user's request
    Paremeter: opt(int)
    return: None
    """
    client = boto3.session.Session().client('ec2', 'us-east-1')
    print("""
        1. start
        2. stop
        3. terminate
        4. Exit
    """)
    option = int(input("please select your option above."))
    if option == 1:
        print("Starting all instances.....")
        client.start_instances(InstanceIds=instance_ids)
        time.sleep(20)
        print("started instances!!.....")
    elif option == 2:
        print("Stopping all instances.....")
        client.stop_instances(InstanceIds=instance_ids)
        time.sleep(20)
        print("instances stopped!!.....")
    elif option == 3:
        print("terminating all instances.....")
        client.terminate_instances(InstanceIds=instance_ids)
        time.sleep(35)
        print("Instances terminated!!...")
    elif option == 4:
        # sys.exit()
        print("exit")
    else:
        print(f"{option} is invalid. please provide a valid option and try again.")
    return None

melo_driven_script()
# Out:
#         1. start
#         2. stop
#         3. terminate
#         4. Exit
#
# please select your option above.3
# terminating all instances.....
# Instances terminated!!...

# %%
def volume_type():
    client = boto3.session.Session().client('ec2', 'us-east-1')
    response = client.describe_volumes()['Volumes']
    pprint(response)
    
    
volume_type()
# Out:
# [{'Attachments': [{'AttachTime': datetime.datetime(2022, 6, 25, 17, 9, 5, tzinfo=tzutc()),
#                    'DeleteOnTermination': True,
#                    'Device': '/dev/xvda',
#                    'InstanceId': 'i-006036d9646165a19',
#                    'State': 'attached',
#                    'VolumeId': 'vol-0675a685649c7aec6'}],
#   'AvailabilityZone': 'us-east-1b',
#   'CreateTime': datetime.datetime(2022, 6, 25, 17, 9, 5, 991000, tzinfo=tzutc()),
#   'Encrypted': False,
#   'Iops': 100,
#   'MultiAttachEnabled': False,
#   'Size': 8,
#   'SnapshotId': 'snap-0c87771c8e09de699',
#   'State': 'in-use',
#   'VolumeId': 'vol-0675a685649c7aec6',
#   'VolumeType': 'gp2'},
#  {'Attachments': [{'AttachTime': datetime.datetime(2022, 6, 25, 17, 23, 51, tzinfo=tzutc()),
#                    'DeleteOnTermination': True,
#                    'Device': '/dev/xvda',
#                    'InstanceId': 'i-0a72f0b2a06166c23',
#                    'State': 'attached',
#                    'VolumeId': 'vol-0beae5474d67a99ee'}],
#   'AvailabilityZone': 'us-east-1b',
#   'CreateTime': datetime.datetime(2022, 6, 25, 17, 23, 51, 946000, tzinfo=tzutc()),
#   'Encrypted': False,
#   'Iops': 100,
#   'MultiAttachEnabled': False,
#   'Size': 8,
#   'SnapshotId': 'snap-0c87771c8e09de699',
#   'State': 'in-use',
#   'VolumeId': 'vol-0beae5474d67a99ee',
#   'VolumeType': 'gp2'},
#  {'Attachments': [{'AttachTime': datetime.datetime(2022, 6, 25, 17, 0, 14, tzinfo=tzutc()),
#                    'DeleteOnTermination': True,
#                    'Device': '/dev/xvda',
#                    'InstanceId': 'i-0402675382b992f7a',
#                    'State': 'attached',
#                    'VolumeId': 'vol-0b5d6b8086075e6fb'}],
#   'AvailabilityZone': 'us-east-1a',
#   'CreateTime': datetime.datetime(2022, 6, 25, 17, 0, 14, 595000, tzinfo=tzutc()),
#   'Encrypted': False,
#   'Iops': 100,
#   'MultiAttachEnabled': False,
#   'Size': 8,
#   'SnapshotId': 'snap-08f1069dfde2007ba',
#   'State': 'in-use',
#   'VolumeId': 'vol-0b5d6b8086075e6fb',
#   'VolumeType': 'gp2'},
#  {'Attachments': [{'AttachTime': datetime.datetime(2022, 6, 25, 17, 0, 14, tzinfo=tzutc()),
#                    'DeleteOnTermination': True,
#                    'Device': '/dev/xvda',
#                    'InstanceId': 'i-09135aa74c2e472d7',
#                    'State': 'attached',
#                    'VolumeId': 'vol-0f2b58920eeb50227'}],
#   'AvailabilityZone': 'us-east-1a',
#   'CreateTime': datetime.datetime(2022, 6, 25, 17, 0, 14, 533000, tzinfo=tzutc()),
#   'Encrypted': False,
#   'Iops': 100,
#   'MultiAttachEnabled': False,
#   'Size': 8,
#   'SnapshotId': 'snap-08f1069dfde2007ba',
#   'State': 'in-use',
#   'VolumeId': 'vol-0f2b58920eeb50227',
#   'VolumeType': 'gp2'},
#  {'Attachments': [{'AttachTime': datetime.datetime(2022, 6, 25, 17, 0, 14, tzinfo=tzutc()),
#                    'DeleteOnTermination': True,
#                    'Device': '/dev/xvda',
#                    'InstanceId': 'i-089999e2cced39b86',
#                    'State': 'attached',
#                    'VolumeId': 'vol-0b7f76083002c8169'}],
#   'AvailabilityZone': 'us-east-1a',
#   'CreateTime': datetime.datetime(2022, 6, 25, 17, 0, 14, 574000, tzinfo=tzutc()),
#   'Encrypted': False,
#   'Iops': 100,
#   'MultiAttachEnabled': False,
#   'Size': 8,
#   'SnapshotId': 'snap-08f1069dfde2007ba',
#   'State': 'in-use',
#   'VolumeId': 'vol-0b7f76083002c8169',
#   'VolumeType': 'gp2'},
#  {'Attachments': [{'AttachTime': datetime.datetime(2022, 6, 25, 17, 9, 5, tzinfo=tzutc()),
#                    'DeleteOnTermination': True,
#                    'Device': '/dev/xvda',
#                    'InstanceId': 'i-03ddf11ab7549eb7c',
#                    'State': 'attached',
#                    'VolumeId': 'vol-06f6e94bc49173647'}],
#   'AvailabilityZone': 'us-east-1a',
#   'CreateTime': datetime.datetime(2022, 6, 25, 17, 9, 5, 936000, tzinfo=tzutc()),
#   'Encrypted': False,
#   'Iops': 100,
#   'MultiAttachEnabled': False,
#   'Size': 8,
#   'SnapshotId': 'snap-0c87771c8e09de699',
#   'State': 'in-use',
#   'VolumeId': 'vol-06f6e94bc49173647',
#   'VolumeType': 'gp2'},
#  {'Attachments': [{'AttachTime': datetime.datetime(2022, 6, 25, 17, 23, 51, tzinfo=tzutc()),
#                    'DeleteOnTermination': True,
#                    'Device': '/dev/xvda',
#                    'InstanceId': 'i-0e71149d7fa423afc',
#                    'State': 'attached',
#                    'VolumeId': 'vol-021ab91dd76444864'}],
#   'AvailabilityZone': 'us-east-1a',
#   'CreateTime': datetime.datetime(2022, 6, 25, 17, 23, 51, 947000, tzinfo=tzutc()),
#   'Encrypted': False,
#   'Iops': 100,
#   'MultiAttachEnabled': False,
#   'Size': 8,
#   'SnapshotId': 'snap-0c87771c8e09de699',
#   'State': 'in-use',
#   'VolumeId': 'vol-021ab91dd76444864',
#   'VolumeType': 'gp2'}]

# %%
def create_ec2_instance():
     """This function is to create ec2 instance
    Paremeter: opt(int)
    return: None
    """
    client = boto3.session.Session().client('ec2', 'us-east-1')
    print(dir(client))
    return None

create_ec2_instance()
# Out:
#   File <tokenize>:6
#     client = boto3.session.Session().client('ec2', 'us-east-1')
#     ^
# IndentationError: unindent does not match any outer indentation level
